# %%
import pandas as pd

# %%
df = pd.read_csv('TrainingCourses.csv')
df
# Out:
#              Date  Duration  \
# 0      March 2024  Two hour
# 1   November 2023   Two day
# 2     August 2023  Half day
# 3      April 2023  Two hour
# 4      March 2023  Two hour
# 5    October 2022  Half day
# 6   November 2022   Two day
# 7       July 2022  Five day
# 8        May 2022   Two day
# 9      March 2022   Two day
# 10  December 2021  Half day
# 11       May 2022   One day
# 12  November 2021   One day
# 13  November 2021  Half day
#
#                                              Customer  \
# 0                              University of Plymouth
# 1                                           SENSE CDT
# 2                     Trevor Platt Science Foundation
# 3                     Trevor Platt Science Foundation
# 4    Open Network for Water Related Diseases (ONWARD)
# 5                         NEODAAS/FSF Training Course
# 6                                           SENSE CDT
# 7                                            PORTWIMS
# ...

# %%
for idx,row in df.iterrows():
#     print(idx,row)
    with open(f'{idx}_course.md', 'w') as fh:
        fh.write(f'---\n')
        fh.write(f'title: "{row.Customer} - {row.Title}"\n')
        fh.write(f'collection: teaching\n')
        fh.write(f'type: "{row.Duration}, {row.Participants} participants {row.Location}. {row.Support}"\n')
#         fh.write(f'permalink: /teaching/2021-NEODAAS-Training-Course')
#         fh.write(f'venue: "NEODAAS, AI4EO"')
        fh.write(f'date: {row.Date}\n')
#         fh.write(f'location: "Plymouth, UK"')
        fh.write(f'---\n')
